# %%
import os
os.environ["DDE_BACKEND"] = "pytorch"
import deepxde as dde
# Out:
# Using backend: pytorch
# Other supported backends: tensorflow.compat.v1, tensorflow, jax, paddle.
# paddle supports more examples now and is recommended.

# %%
net_size = [3, 100, 3, 100]  # branch_input, branch_hidden, trunk_input, trunk_hidden
dim_x = 1  # trunk input dimension
branch_size = 100
for _ in range(net_size[0]):
    branch_size.append(net_size[1])
branch_size[-1] = 32
trunk_size = [dim_x]
for _ in range(net_size[2]):
    trunk_size.append(net_size[3])
trunk_size[-1] = 32
net = dde.nn.DeepONet(branch_size, trunk_size, "tanh", "Glorot normal",)
